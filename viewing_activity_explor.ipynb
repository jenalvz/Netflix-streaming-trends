# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# import view activity report
viewing_activity_to_load = "Resources/CONTENT_INTERACTION/ViewingActivity.csv"

# read data
viewing_activity = pd.read_csv(viewing_activity_to_load)

#display df head for preview
viewing_activity.head()

# ran using downg_sqlalch environment
# Out:
#               Profile Name           Start Time  Duration  \
# 0  El amigo de la que paga  2023-08-02 01:15:41  00:05:01
# 1  El amigo de la que paga  2023-08-02 01:15:10  00:00:15
# 2  El amigo de la que paga  2023-08-02 01:14:22  00:00:19
# 3  El amigo de la que paga  2023-08-02 01:12:14  00:01:02
# 4  El amigo de la que paga  2023-08-02 01:11:44  00:00:24
#
#                                     Attributes  \
# 0  Autoplayed: user action: User_Interaction;
# 1              Autoplayed: user action: None;
# 2              Autoplayed: user action: None;
# 3              Autoplayed: user action: None;
# 4              Autoplayed: user action: None;
#
#                                                Title Supplemental Video Type  \
# 0                   Missing: The Lucie Blackman Case                     NaN
# 1                        Prisoners_hook_primary_16x9                    HOOK
# 2              Trailer: Unknown: Cosmic Time Machine                 TRAILER
# ...
